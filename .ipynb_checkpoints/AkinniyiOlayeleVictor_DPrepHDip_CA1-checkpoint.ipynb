# %%
# Importing the Panda DataFrame libraries

import warnings
warnings.filterwarnings('ignore')
import os, sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from datetime import datetime 
import seaborn as sns
from scipy import stats
sns.set()

# %%
# Loading data into the DataFrame

df_sales = pd.read_csv('vgsales.csv')

# %%
# View the first five rows to know what the dataset looks like

df_sales.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# 0          51.0          8       322.0  Nintendo      E
# 1           NaN        NaN         NaN       NaN    NaN
# 2          73.0        8.3       709.0  Nintendo      E
# 3          73.0          8       192.0  Nintendo      E
# 4           NaN        NaN         NaN       NaN    NaN

# %% [markdown]
# ## Data Preparation
# * Understanding the data variables
# * Cleaning the dataset( missing data, redundant data, outliers)

# %%
# I want to do the characterisation of the data set: size; number of attributes; has/does not have missing values,number of observations.

# I want to know the number of attributes/ observations in the dataset

df_sales.shape
# Out:
# (16719, 16)

# %%
# Checking the data type of the attributes present in the dataset


df_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16717 non-null  object
#  1   Platform         16719 non-null  object
#  2   Year_of_Release  16450 non-null  float64
#  3   Genre            16717 non-null  object
#  4   Publisher        16665 non-null  object
#  5   NA_Sales         16719 non-null  float64
#  6   EU_Sales         16719 non-null  float64
#  7   JP_Sales         16719 non-null  float64
#  8   Other_Sales      16719 non-null  float64
#  9   Global_Sales     16719 non-null  float64
#  10  Critic_Score     8137 non-null   float64
#  11  Critic_Count     8137 non-null   float64
#  12  User_Score       10015 non-null  object
#  13  User_Count       7590 non-null   float64
#  14  Developer        10096 non-null  object
#  15  Rating           9950 non-null   object
# dtypes: float64(9), object(7)
# memory usage: 2.0+ MB

# %%
# Check for missing values 

df_sales.isnull().sum()
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# Publisher            54
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8582
# Critic_Count       8582
# User_Score         6704
# User_Count         9129
# Developer          6623
# Rating             6769
# dtype: int64

# %%
# Checking for duplicates

df_sales.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Observations
# * There are 16719 observations and 16 attributes.
# * There are missing values
# * The amount of missing values vary all through each columns of the dataset
# * There are not duplicates in the dataset

# %% [markdown]
# #### Since there is not constant amount of missing values all through the columns, we will pick the column with  the missing value percentage and lowest percentage to scale. This will give us the best way to treat the missing values. Maybe to delete or fill in.

# %%
# scaling percentage of missing value in Critic_Score column

#calculting isnull() % for 'Critic_Score'
df_sales[df_sales['Critic_Score'].isnull()].shape[0]* 100 / len(df_sales)
# Out:
# 51.330821221364914

# %%
# scaling percentage of missing value in Publisher column

#calculting isnull() % for 'Publisher'
df_sales[df_sales['Publisher'].isnull()].shape[0]* 100 / len(df_sales)
# Out:
# 0.32298582451103536

# %% [markdown]
# ### The percentage of missing values is varies all through the dataset.
# * The ways to fill it in with KNN imputer for numerical values, fill in with mode for categorical values to avoid bias as the some columns with missing values are above 20 percent.
# * I will also look into my descriptive analysis to see how the outcome will affect the statistical results.

# %%
### Descriptive statistics:
df_sales.describe()
# Out:
#        Year_of_Release      NA_Sales      EU_Sales      JP_Sales  \
# count     16450.000000  16719.000000  16719.000000  16719.000000
# mean       2006.487356      0.263330      0.145025      0.077602
# std           5.878995      0.813514      0.503283      0.308818
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2020.000000     41.360000     28.960000     10.220000
#
#         Other_Sales  Global_Sales  Critic_Score  Critic_Count    User_Count
# count  16719.000000  16719.000000   8137.000000   8137.000000   7590.000000
# mean       0.047332      0.533543     68.967679     26.360821    162.229908
# std        0.186710      1.547935     13.938165     18.980495    561.282326
# min        0.000000      0.010000     13.000000      3.000000      4.000000
# 25%        0.000000      0.060000     60.000000     12.000000     10.000000
# 50%        0.010000      0.170000     71.000000     21.000000     24.000000
# 75%        0.030000      0.470000     79.000000     36.000000     81.000000
# max       10.570000     82.530000     98.000000    113.000000  10665.000000

# %% [markdown]
# # Before we start the general KNN Imputer, we will treat some columns separately due to the data dictionary.
# * Looking at the Data Dictionary, 'User_Score' column will be treated differently so as to avoid Mode treating it as Object.

# %%
df_sales['User_Score'].unique()
# Out:
# array(['8', nan, '8.3', '8.5', '6.6', '8.4', '8.6', '7.7', '6.3', '7.4',
#        '8.2', '9', '7.9', '8.1', '8.7', '7.1', '3.4', '5.3', '4.8', '3.2',
#        '8.9', '6.4', '7.8', '7.5', '2.6', '7.2', '9.2', '7', '7.3', '4.3',
#        '7.6', '5.7', '5', '9.1', '6.5', 'tbd', '8.8', '6.9', '9.4', '6.8',
#        '6.1', '6.7', '5.4', '4', '4.9', '4.5', '9.3', '6.2', '4.2', '6',
#        '3.7', '4.1', '5.8', '5.6', '5.5', '4.4', '4.6', '5.9', '3.9',
#        '3.1', '2.9', '5.2', '3.3', '4.7', '5.1', '3.5', '2.5', '1.9', '3',
#        '2.7', '2.2', '2', '9.5', '2.1', '3.6', '2.8', '1.8', '3.8', '0',
#        '1.6', '9.6', '2.4', '1.7', '1.1', '0.3', '1.5', '0.7', '1.2',
#        '2.3', '0.5', '1.3', '0.2', '0.6', '1.4', '0.9', '1', '9.7'],
#       dtype=object)

# %% [markdown]
# #### From the above we observe that there is a text in the column and this is the reason why the column showing as Object data type. We will to treat that first before treating the missing values.
# * We have to convert 'tbd' to missing values, so Panda recognizes it as missing value.

# %%
df_sales = pd.read_csv('vgsales.csv', na_values='tbd')

# %%
df_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16717 non-null  object
#  1   Platform         16719 non-null  object
#  2   Year_of_Release  16450 non-null  float64
#  3   Genre            16717 non-null  object
#  4   Publisher        16665 non-null  object
#  5   NA_Sales         16719 non-null  float64
#  6   EU_Sales         16719 non-null  float64
#  7   JP_Sales         16719 non-null  float64
#  8   Other_Sales      16719 non-null  float64
#  9   Global_Sales     16719 non-null  float64
#  10  Critic_Score     8137 non-null   float64
#  11  Critic_Count     8137 non-null   float64
#  12  User_Score       7590 non-null   float64
#  13  User_Count       7590 non-null   float64
#  14  Developer        10096 non-null  object
#  15  Rating           9950 non-null   object
# dtypes: float64(10), object(6)
# memory usage: 2.0+ MB

# %% [markdown]
# #### Now we can go ahead to treat our missing values.

# %%
# Filling missing values with KNN Imputer

from sklearn.impute import KNNImputer

# Identify numerical columns
numeric_columns = df_sales.select_dtypes(include=['float64']).columns

# Extract only the numerical columns for KNN imputation
df_numeric = df_sales[numeric_columns]

# Apply KNN imputation for missing values on numerical columns
imputer = KNNImputer(n_neighbors=5)
df_numeric_imputed = pd.DataFrame(imputer.fit_transform(df_numeric), columns=df_numeric.columns)

# Replace the missing values in the original DataFrame with imputed values
df_sales[numeric_columns] = df_numeric_imputed

# Display the DataFrame after KNN imputation
df_sales.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24          79.2
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37          81.4
#
#    Critic_Count  User_Score  User_Count Developer Rating
# 0          51.0        8.00       322.0  Nintendo      E
# 1          66.4        7.96       411.0       NaN    NaN
# 2          73.0        8.30       709.0  Nintendo      E
# 3          73.0        8.00       192.0  Nintendo      E
# 4          64.6        8.08       465.4       NaN    NaN

# %%
### Now will treat categorical missing values with mode

# Identify categorical columns
categorical_columns = df_sales.select_dtypes(include=['object']).columns

# Fill missing values with the mode for categorical columns
df_sales[categorical_columns] = df_sales[categorical_columns].fillna(df_sales[categorical_columns].mode().iloc[0])

# Check for missing values 

df_sales.isnull().sum()
# Out:
# Name               0
# Platform           0
# Year_of_Release    0
# Genre              0
# Publisher          0
# NA_Sales           0
# EU_Sales           0
# JP_Sales           0
# Other_Sales        0
# Global_Sales       0
# Critic_Score       0
# Critic_Count       0
# User_Score         0
# User_Count         0
# Developer          0
# Rating             0
# dtype: int64

# %%
# Checking the data type of the attributes present in the dataset


df_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16719 non-null  object
#  1   Platform         16719 non-null  object
#  2   Year_of_Release  16719 non-null  float64
#  3   Genre            16719 non-null  object
#  4   Publisher        16719 non-null  object
#  5   NA_Sales         16719 non-null  float64
#  6   EU_Sales         16719 non-null  float64
#  7   JP_Sales         16719 non-null  float64
#  8   Other_Sales      16719 non-null  float64
#  9   Global_Sales     16719 non-null  float64
#  10  Critic_Score     16719 non-null  float64
#  11  Critic_Count     16719 non-null  float64
#  12  User_Score       16719 non-null  float64
#  13  User_Count       16719 non-null  float64
#  14  Developer        16719 non-null  object
#  15  Rating           16719 non-null  object
# dtypes: float64(10), object(6)
# memory usage: 2.0+ MB

# %%
df_sales.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24          79.2
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37          81.4
#
#    Critic_Count  User_Score  User_Count Developer Rating
# 0          51.0        8.00       322.0  Nintendo      E
# 1          66.4        7.96       411.0   Ubisoft      E
# 2          73.0        8.30       709.0  Nintendo      E
# 3          73.0        8.00       192.0  Nintendo      E
# 4          64.6        8.08       465.4   Ubisoft      E

# %% [markdown]
# #### Now will treat the inconsistency in the data types, so we can have the perfect data types according to the data dictionary
# * If we change the data type directly to int64 it will affect the values, so will round some of the floats to the nearest decimal and integer and convert it to int64 after the round up.
# * This will make it easy for us to work more better with the dataset and to see more clearly each variables observation.

# %%
# Identify numerical columns
numeric_columns = df_sales.select_dtypes(include=['float64']).columns

# Columns to round up to integers
columns_to_round_int = ['Year_of_Release', 'Critic_Score', 'Critic_Count',  'User_Count'] 

# Columns to round to floats with 2 decimal places (rest of the numerical columns)
columns_to_round_float = [col for col in numeric_columns if col not in columns_to_round_int]

# Round up specific numerical columns to integers
df_sales[columns_to_round_int] = df_sales[columns_to_round_int].round(0).astype(int)


# Display the DataFrame after rounding
df_sales.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii             2006        Sports  Nintendo
# 1         Super Mario Bros.      NES             1985      Platform  Nintendo
# 2            Mario Kart Wii      Wii             2008        Racing  Nintendo
# 3         Wii Sports Resort      Wii             2009        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB             1996  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53            76
# 1     29.08      3.58      6.81         0.77         40.24            79
# 2     15.68     12.76      3.79         3.29         35.52            82
# 3     15.61     10.93      3.28         2.95         32.77            80
# 4     11.27      8.89     10.22         1.00         31.37            81
#
#    Critic_Count  User_Score  User_Count Developer Rating
# 0            51        8.00         322  Nintendo      E
# 1            66        7.96         411   Ubisoft      E
# 2            73        8.30         709  Nintendo      E
# 3            73        8.00         192  Nintendo      E
# 4            65        8.08         465   Ubisoft      E

# %%
# Checking the Data Types to see if they match the Data Dictionary

df_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16719 non-null  object
#  1   Platform         16719 non-null  object
#  2   Year_of_Release  16719 non-null  int32
#  3   Genre            16719 non-null  object
#  4   Publisher        16719 non-null  object
#  5   NA_Sales         16719 non-null  float64
#  6   EU_Sales         16719 non-null  float64
#  7   JP_Sales         16719 non-null  float64
#  8   Other_Sales      16719 non-null  float64
#  9   Global_Sales     16719 non-null  float64
#  10  Critic_Score     16719 non-null  int32
#  11  Critic_Count     16719 non-null  int32
#  12  User_Score       16719 non-null  float64
#  13  User_Count       16719 non-null  int32
#  14  Developer        16719 non-null  object
#  15  Rating           16719 non-null  object
# dtypes: float64(6), int32(4), object(6)
# memory usage: 1.8+ MB

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ### Question 1: What are the top 5 games by global sales?

# %%
### Creating Dataframes to solve the calculation before Visualization 
# Calculating the top 5 games sold globally.
top_5_games_sold = df_sales[['Name', 'Global_Sales']].nlargest(5, 'Global_Sales')

# %%
plt.figure(figsize=(5, 3))
sns.barplot(data= top_5_games_sold, x='Global_Sales', y='Name', palette='pastel')
plt.xlabel('Global Sales', fontsize=12, color="blue")
plt.ylabel('Name', fontsize=12, color="blue")
plt.title('Top 5 Games by Global Sales', fontsize=15, color='black')
plt.show()

# %% [markdown]
# ### Question 2: Is there a correlation between the “na_sales” and “jp_sales” for the years 2010-2014?

# %%
# Creating dataframe for the year between 2010 - 2014

sales_2010_2014 = df_sales[(df_sales['Year_of_Release'] >= 2010) & (df_sales['Year_of_Release'] <= 2014)]

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=sales_2010_2014, x='NA_Sales', y='JP_Sales',hue='Year_of_Release', palette='viridis', alpha=0.7);
plt.legend(loc='upper right', bbox_to_anchor=(1.2,1));
plt.xlabel('NA Sales', fontsize=12, color="blue")
plt.ylabel('JP Sales', fontsize=12, color="blue")
plt.title('Correlation between NA Sales and JP Sales (2010-2014)', fontsize=15, color='black')
plt.show();

# %% [markdown]
# ### Question 3: What is the distribution of the most popular 4 game genres?

# %%
# Creating DataFrame for the top 4 genres

top_4_genres = df_sales['Genre'].value_counts().nlargest(4)

# %%
plt.figure(figsize=(5, 3))
sns.barplot(x=top_4_genres.index, y=top_4_genres.values, palette = 'Set2');
plt.xlabel('Genre', fontsize=12, color="blue")
plt.ylabel('Number of Games', fontsize=12, color="blue")
plt.title('Distribution of Top 4 Game Genres',fontsize=15, color='black')
plt.xticks(rotation= 30)
plt.show();

# %% [markdown]
# ### Question 4: Do older games (2005 and earlier) have a higher MEAN “eu_sales” than newer games (after 2005)?

# %%
# Creating dataframe to group the year for clear visualization
df_sales['year_group'] = 'Older (<=2005)'
df_sales.loc[df_sales['Year_of_Release'] > 2005, 'year_group'] = 'Newer (>2005)'

# %%
plt.figure(figsize=(5,3))
sns.barplot(data=df_sales, x='year_group', y='EU_Sales',  estimator=mean);
plt.xlabel('Year Group', fontsize=12, color="blue")
plt.ylabel('EU Sales', fontsize=12, color="blue")
plt.title('Average EU Sales Comparison between Older and Newer Games',fontsize=15, color='black');

# %% [markdown]
# ### Question 5: What are the 3 most common “developer” in the dataset?

# %%
# Calculating and creating DataFrame for the value count for Developers

top_3_developer= df_sales['Developer'].value_counts().head(3)

top_3_developer
# Out:
# Ubisoft      6827
# EA Sports     172
# EA Canada     167
# Name: Developer, dtype: int64

# %%
top_3_developer.index
# Out:
# Index(['Ubisoft', 'EA Sports', 'EA Canada'], dtype='object')

# %%
top_3_developer.values
# Out:
# array([6827,  172,  167], dtype=int64)

# %%
plt.figure(figsize=(5,3))
plt.bar(x=top_3_developer.index, height=top_3_developer.values,color=['green','yellow','red'])
plt.xticks(rotation= 30)
plt.xlabel("Name of Developers", fontsize=12, color="blue")
plt.ylabel("Count of Developers", fontsize=12, color="blue")
plt.title("3 Most common Developers", fontsize=15, color="black")
plt.show()

# %% [markdown]
# ## Part 2: Does the Critic score have a significant impact on Global sales compared to User score?

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_sales, x='User_Score', y='Global_Sales', color='blue', alpha=0.7);
plt.xlabel('User Score', fontsize=12, color='black')
plt.ylabel('Global Sales (in millions)' , fontsize=12, color='black')
plt.title('User Score vs Global Sales', fontsize=15, color='black')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_sales, x='Critic_Score', y='Global_Sales', color='blue', alpha=0.7);
plt.xlabel('Critic Score', fontsize=12, color='black')
plt.ylabel('Global Sales (in millions)' , fontsize=12, color='black')
plt.title('Critic Score vs Global Sales', fontsize=15, color='black')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Part 3

# %% [markdown]
# My choice of specific methods for engineering the data and visualization was driven by the need to effectively explore and communicate insights from the dataset. By leveraging appropriate techniques and design decisions, the visualizations were optimized for clarity, readability, and insight generation so that it can be easily read by all not only a data analyst but also a non technical person can easy look at the visualization and be able to capture it within the 5 minutes.
#
# I explored some Engineering model like sing nlargest() and head(),I utilized nlargest() and head() functions to quickly identify the top or most common variables in the dataset. This approach is efficient for exploring the dataset and identifying key insights without having to manually sort or filter the data.
#
#  After this I performed calculations to create new DataFrames that enhance the visibility of the visualization. For example, calculating top_4_genres or top_5_games_sold values for specific groups allowed for clearer comparisons and insights.
#
# My choice of visualization types are Barplot and Scatterplot in seaborn library. I used only this two all through the project because I want to make it simple and easy to relate with.
# I used bar charts to visualize categorical data and comparisons between different categories. Bar charts are effective in representing discrete categories and showing relative differences in values. The choice of bar charts was suitable for displaying top 5 games by global sales, distribution of top 4 game genres,Average EU Sales Comparison between Older and Newer Games and the most common developers.
# While Scatter plots were chosen to visualize relationships between numerical variables, such as critic score and global sales, Correlation between NA Sales and JP Sales. Scatter plots are useful for identifying patterns, trends, or correlations between variables.
#
# I used a consistent color scheme across all visualizations to maintain coherence and readability. For example, I used blue for labels and titles to ensure they stand out against the background and are easily visible.
# I chose black color for titles to provide a clear contrast against the background and ensure readability. Black color is often associated with formal and professional settings, making it suitable for titles.
#
# I adjusted the size of the figures using plt.figure(figsize=(width, height)) to ensure the visualizations are appropriately sized and have enough space for elements without appearing cluttered.
# I rotated the x-axis labels by 30 degrees using plt.xticks(rotation=30) to prevent overlapping of labels and improve readability, especially for long category names or numerical values. I used descriptive titles for each visualization to convey the purpose and context of the plot. Descriptive titles help viewers understand the main takeaway or insight from the visualization at a glance. I chose a larger font size for titles (fontsize=15) to make them prominent and draw attention to the main message of the visualization.
#
# My rationale for the visualization created in Part 2 is because Scatter plots are useful for identifying patterns, trends, or correlations between variables.I want to know the relationship between critic scores and user scores with global sales, how they correlate and affect the global sales,I want to know if their critics and scores brings positive or negative effect on sales. It can provide valuable insights into the influence of professional critics' opinions versus user opinions on the success of video games in terms of sales. This analysis can help game developers and publishers understand the importance of catering to different audiences and how critical acclaim versus user satisfaction affects sales.
# If we look at the two scatterplots comparison, we will see that we do not have many customer with 10 user score on the games but as their user score increases sales also increases between 4 - 8 user score, we can see the global sales rises, while as critic score goes higher there is a decrease in global sales, hereby affecting the global sales.
# Developer needs to pay more attention to user satisfaction

# %% [markdown]
# ## Reference
# * Vikas Ukani. (2021) 'Video Game Sales EDA, Visualizations, ML Models' Available at: https://www.kaggle.com/code/vikasukani/video-game-sales-eda-visualizations-ml-models (Accessed: 1 April 2024).
# * HKubra K. (2019) 'VideoGamesSales_Visualization' Available at: https://www.kaggle.com/code/hkubra/videogamessales-visualization (Accessed on: 2 April 2024 ).
# * pandas Development Team. (n.d.). pandas.DataFrame.nlargest. [Online] Available at: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.nlargest.html (Accessed: 3 April 2024).
# * seaborn Development Team. (n.d.). seaborn.color_palette. [Online] Available at: https://seaborn.pydata.org/generated/seaborn.color_palette.html#seaborn.color_palette (Accessed: 3 April 2024).
# * Rachael Tatman, 2017,n.d. Kaggle. Handling Missing Values https://www.kaggle.com/code/rtatman/data-cleaning-challenge-handling-missing-values
